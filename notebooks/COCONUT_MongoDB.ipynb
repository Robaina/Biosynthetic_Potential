# %% [markdown]
# # Parsing and searching the COCONUT database for Natural Products
#
# [COCONUT](https://coconut.naturalproducts.net) is a database of natural products. It contains information about the natural products, their structures, and chemical properties. In this notebook, we will parse the COCONUT database (a MongoDB database) and search for natural products by their names.
#
# COCONUT contains the following fields:
#
# 1. **_id**: MongoDB's unique object identifier for each document.
# 2. **coconut_id**: A unique identifier specific to the COCONUT database.
# 3. **contains_sugar**: A boolean flag indicating the presence of sugar in the compound.
# 4. **heavy_atom_number**: The number of heavy atoms (non-hydrogen) in the molecule.
# 5. **inchi**: The International Chemical Identifier (InChI) string.
# 6. **inchikey**: A hash of the InChI string, used for quick database searches.
# 7. **smiles**: The Simplified Molecular Input Line Entry System string describing the molecule's structure.
# 8. **unique_smiles**: A canonical SMILES string that uniquely identifies the molecule.
# 9. **clean_smiles**: A cleaned-up version of the SMILES string.
# 10. **sugar_free_smiles**: SMILES string of the molecule without any sugar moieties.
# 11. **deep_smiles**: An alternative SMILES notation potentially capturing deeper structure.
# 12. **name**: Common name of the chemical compound.
# 13. **nameTrustLevel**: A numerical trust level associated with the provided name.
# 14. **annotationLevel**: A numerical level indicating the depth of annotation data available.
# 15. **synonyms**: A list of other names by which the compound is known.
# 16. **cas**: The Chemical Abstracts Service registry number.
# 17. **iupac_name**: The systematic name according to the International Union of Pure and Applied Chemistry.
# 18. **contains_ring_sugars**: A boolean indicating if ring sugars are present.
# 19. **contains_linear_sugars**: A boolean indicating if linear sugars are present.
# 20. **collection**: A list indicating collections or categories the compound belongs to.
# 21. **molecular_formula**: The molecular formula of the compound.
# 22. **molecular_weight**: The calculated molecular weight of the compound.
# 23. **geoLocation**: A list of geographic locations associated with the compound.
# 24. **npl_noh_score**, **npl_score**, **npl_sugar_score**: Various scores related to natural product likeness.
# 25. **number_of_carbons**, **number_of_nitrogens**, **number_of_oxygens**: Counts of specific atom types.
# 26. **max_number_of_rings**, **min_number_of_rings**: The range of ring structures in the compound.
# 27. **sugar_free_heavy_atom_number**: Heavy atom count excluding sugars.
# 28. **sugar_free_total_atom_number**, **total_atom_number**: Counts of total atoms, with and without sugars.
# 29. **bond_count**: The total number of chemical bonds in the molecule.
# 30. **found_in_databases**: A list of databases where this compound is registered.
# 31. **xrefs**: External references with IDs and links to databases.
# 32. **fragments**: A dictionary describing molecular fragments present.
# 33. **fragmentsWithSugar**: Descriptions of molecular fragments including sugar components.
# 34. **murko_framework**: The Murcko scaffold which represents the core structure.
# 35. **ertlFunctionalFragments**, **ertlFunctionalFragmentsPseudoSmiles**: Functional fragment descriptors.
# 36. **pubchemFingerprint**, **pfCounts**: A compact binary fingerprint and count information for PubChem.
# 37. **circularFingerprint**: Circular fingerprinting typically used for structural similarity.
# 38. **extendedFingerprint**: Extended fingerprint data for more detailed structural information.
# 39. **alogp**, **alogp2**, **amralogp**, **apol**, **bcutDescriptor**, **bpol**: Various computed chemical properties and descriptors.
# 40. **eccentricConnectivityIndexDescriptor**, **fmfDescriptor**, **fsp3**: More molecular descriptors related to shape, connectivity, and saturation.
# 41. **fragmentComplexityDescriptor**, **gravitationalIndexHeavyAtoms**: Complexity and gravitational index descriptors.
# 42. **hBondAcceptorCount**, **hBondDonorCount**: Count of hydrogen bond acceptors and donors.
# 43. **hybridizationRatioDescriptor**, **kappaShapeIndex1**, **kappaShapeIndex2**, **kappaShapeIndex3**: Hybridization and kappa shape indices.
# 44. **manholdlogp**, **petitjeanNumber**, **petitjeanShapeTopo**, **petitjeanShapeGeom**: LogP values, Petitjean number, and shape descriptors.
# 45. **lipinskiRuleOf5Failures**: Number of violations of Lipinski's Rule of 5.
# 46. **numberSpiroAtoms**, **vabcDescriptor**, **vertexAdjMagnitude**: Count of spiro atoms and vertex adjacency magnitude.
# 47. **weinerPathNumber**, **weinerPolarityNumber**: Weiner path and polarity numbers.
# 48. **xlogp**, **zagrebIndex**, **topoPSA**:
#
#  LogP value, Zagreb index, and topological polar surface area.
# 49. **tpsaEfficiency**: Efficiency of the topological polar surface area.
# 50. **_class**: Classification path in the COCONUT database.
#
#
# The NPL score ranges between −5 (if the compound is more similar to a synthetic compound) and 5 (if the compound is more similar to a natural product (https://www.sciencedirect.com/science/article/pii/S2667318523000107)

# %% [markdown]
# ## Read COCONUT MongoDB

# %%
import bson
import pandas as pd

def find_compounds_by_name(bson_path, compound_names):
    # Convert all search names to lower case for case-insensitive comparison
    search_names = set(name.lower() for name in compound_names)
    results = []

    with open(bson_path, 'rb') as file:
        while True:
            # Read a document's size from the first 4 bytes
            doc_size = file.read(4)
            if not doc_size:
                break  # End of file
            
            doc_size = int.from_bytes(doc_size, byteorder='little')
            document_data = doc_size.to_bytes(4, byteorder='little') + file.read(doc_size - 4)
            document = bson.BSON(document_data).decode()

            # Retrieve and normalize the primary name
            compound_name = document.get('name', '').lower()
            # Check against both the 'name' and 'synonyms' fields
            if compound_name in search_names or any(syn.lower() in search_names for syn in document.get('synonyms', [])):
                results.append(document)
    
    return results

def build_compound_dataframe(compounds, columns=None):
    # If no specific columns are requested, use a default list
    if columns is None:
        columns = ['coconut_id', 'name', 'synonyms', 'unique_smiles', 
                   'iupac_name', 'molecular_weight', 'npl_score', 
                   'taxid', 'textTaxa', 'chemicalSuperClass',
                   'chemicalClass', 'chemicalSubClass', 'directParentClassification'
                   ]

    # Prepare data for DataFrame
    data = []
    for compound in compounds:
        # Extract data for each specified column, handling missing keys
        row = {col: compound.get(col, pd.NA) for col in columns}
        data.append(row)
    
    # Create and return the DataFrame
    df = pd.DataFrame(data, columns=columns)
    return df
# Out:
# {'_id': ObjectId('61a5787bc52bda1e67b86a1a'), 'coconut_id': 'CNP0355008', 'contains_sugar': 0, 'heavy_atom_number': 42, 'inchi': 'InChI=1S/C40H52O2/c1-29(17-13-19-31(3)21-23-35-33(5)37(41)25-27-39(35,7)8)15-11-12-16-30(2)18-14-20-32(4)22-24-36-34(6)38(42)26-28-40(36,9)10/h11-24H,25-28H2,1-10H3', 'inchikey': 'FDSDTBUPSURDBL-UHFFFAOYSA-N', 'smiles': '[H]C(C1=C(C(=O)C([H])([H])C([H])([H])C1(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])=C([H])C(=C([H])C([H])=C([H])C(=C([H])C([H])=C([H])C([H])=C(C([H])=C([H])C([H])=C(C([H])=C([H])C2=C(C(=O)C([H])([H])C([H])([H])C2(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]', 'unique_smiles': 'O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C(=O)CCC2(C)C)C)C)C)C)C)C(C)(C)CC1)C', 'clean_smiles': 'O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C(=O)CCC2(C)C)C)C)C)C)C)C(C)(C)CC1)C', 'sugar_free_smiles': 'O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C(=O)CCC2(C)C)C)C)C)C)C)C(C)(C)CC1)C', 'deep_smiles': '', 'name': 'Orobronze', 'nameTrustLevel': 2, 'annotationLevel': 5, 'synonyms': ['Food Orange 8', "4,4'-Dioxo-Beta-Carotene", 'Carophyll Red', "Beta-Carotene-4,4'-Dione", 'Canthaxanthin', 'Orobronze', 'E 161G', "All-Trans-Beta-Carotene-4,4'-Dione"], 'cas': '514-78-3', 'iupac_name': '2,4,4-trimethyl-3-[3,7,12,16-tetramethyl-18-(2,6,6-trimethyl-3-oxocyclohex-1-en-1-yl)octadeca-1,3,5,7,9,11,13,15,17-nonaen-1-yl]cyclohex-2-en-1-one', 'contains_ring_sugars': False, 'contains_linear_sugars': False, 'collection': [], 'molecular_formula': 'C40H52O2', 'molecular_weight': 564.8411649255996, 'geoLocation': ['nogeo'], 'npl_noh_score': 0.8039901234257952, 'npl_score': 0.7148538659345987, 'npl_sugar_score': 0.7382265922010397, 'number_of_carbons': 40, 'number_of_nitrogens': 0, 'number_of_oxygens': 2, 'max_number_of_rings': 2, 'min_number_of_rings': 2, 'sugar_free_heavy_atom_number': 42, 'sugar_free_total_atom_number': 94, 'total_atom_number': 94, 'bond_count': 43, 'found_in_databases': ['np-mrd', 'np_atlas_2019_12', 'fooddb', 'chemspidernp', 'carotenoids', 'respect', 'mnp', 'npatlas', 'chebi_np', 'knapsack', 'gnps', 'unpd', 'npass', 'exposome-explorer', 'pubchem'], 'xrefs': [['chebi_np', 'CHEBI:3362', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['knapsack', 'C00000922', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['knapsack', '228', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['pubchem_tested_np', '10580', 'https://pubchem.ncbi.nlm.nih.gov/compound/'], ['carotenoids', 'CA00471', 'http://carotenoiddb.jp/Entries/'], ['fooddb', 'Canthaxanthin', 'https://foodb.ca/compounds/'], ['chemspidernp', '4444639', 'http://www.chemspider.com/Chemical-Structure.'], ['npatlas', 'b12248', 'https://www.npatlas.org/joomla/index.php/explore/compounds#npaid='], ['np_atlas_2019_12', 'Canthaxanthin', 'https://www.npatlas.org/joomla/index.php/explore/compounds#npaid='], ['knapsack', 'C00000922', 'http://www.knapsackfamily.com/knapsack_core/information.php?sname=C_ID&word='], ['exposome-explorer', 'Canthaxanthin_442', 'http://exposome-explorer.iarc.fr/compounds/'], ['npass', '19075', 'http://bidd2.nus.edu.sg/NPASS/browse_np.php?compound=']], 'fragments': {'[C](=[C]([C][C])[C]([C]=[O])[C]([H][H][H]))': 2, '[C]([C]([C]=[C])[H][H][H])': 6, '[C]([C]([C]=[O])[C]([C][H][H])[H][H])': 2, '[C](=[C]([C][H])[C](=[C][H])[H])': 4, '[C]([C]([C][C][C])[C]([C][H][H])[H][H])': 2, '[C](=[C]([C][C])[C](=[C][H])[H])': 4, '[C](=[C]([C][H])[C](=[C][H])[C]([H][H][H]))': 4, '[C](=[C]([C][C])[C](=[C][H])[C]([C][C][C]))': 2, '[O](=[C]([C][C]))': 2, '[H]([C]([C][H][H]))': 30, '[H]([C]([C][C][H]))': 8, '[C]([C]([C]=[C])[C]([C][H][H])=[O])': 2, '[C]([C]([C]=[C])[C]([C][H][H])[C]([H][H][H])[C]([H][H][H]))': 2, '[C]([C]([C][C][C])[H][H][H])': 4, '[H]([C]([C]=[C]))': 14, '[C]([C]([C]=[C])=[C]([C][H])[H])': 6}, 'fragmentsWithSugar': {'[C](=[C]([C][C])[C]([C]=[O])[C]([H][H][H]))': 2, '[C]([C]([C]=[C])[H][H][H])': 6, '[C]([C]([C]=[O])[C]([C][H ...
# {'_id': ObjectId('61a61828c52bda1e67b9810c'), 'coconut_id': 'CNP0283320', 'contains_sugar': 0, 'heavy_atom_number': 42, 'inchi': 'InChI=1S/C40H56O2/c1-29(17-13-19-31(3)21-23-37-33(5)25-35(41)27-39(37,7)8)15-11-12-16-30(2)18-14-20-32(4)22-24-38-34(6)26-36(42)28-40(38,9)10/h11-24,35-36,41-42H,25-28H2,1-10H3', 'inchikey': 'JKQXZKUSFCKOGQ-UHFFFAOYSA-N', 'smiles': '[H]OC1([H])C([H])([H])C(=C(C([H])=C([H])C(=C([H])C([H])=C([H])C(=C([H])C([H])=C([H])C([H])=C(C([H])=C([H])C([H])=C(C([H])=C([H])C2=C(C([H])([H])C([H])(O[H])C([H])([H])C2(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C(C1([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]', 'unique_smiles': 'OC1CC(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1)C', 'clean_smiles': 'OC1CC(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1)C', 'sugar_free_smiles': 'OC1CC(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1)C', 'deep_smiles': '', 'name': 'Zeaxanthin', 'nameTrustLevel': 1, 'annotationLevel': 5, 'synonyms': ["(3R,3'S)-Zeaxanthin", '4-[18-(4-Hydroxy-2,6,6-Trimethylcyclohex-1-En-1-Yl)-3,7,12,16-Tetramethyloctadeca-1,3,5,7,9,11,13,15,17-Nonaen-1-Yl]-3,5,5-Trimethylcyclohex-3-En-1-Ol', "Beta,Beta-Carotene-3,3'-Diol", '(1R)-4-[(1E,3E,5E,7E,9E,11E,13E,15E,17E)-18-[(4R)-4-Hydroxy-2,6,6-Trimethylcyclohexen-1-Yl]-3,7,12,16-Tetramethyloctadeca-1,3,5,7,9,11,13,15,17-Nonaenyl]-3,5,5-Trimethylcyclohex-3-En-1-Ol', 'Meso-Zeaxanthin', '(R,S)-Zeaxanthin', 'Zeaxanthin', "All-Trans-Beta-Carotene-3,3'-Diol", "(3R,3'S)-zeaxanthin", "3'-Epi-Zeaxanthin", "(3S,3'S)-Zeaxanthin", 'All-Trans-Zeaxanthin', 'Anchovyxanthin', 'all-trans-zeaxanthin', "(3R,3'R)-Dihydroxy-Beta,Beta-Carotene"], 'cas': '31272-50-1', 'iupac_name': '4-[18-(4-hydroxy-2,6,6-trimethylcyclohex-1-en-1-yl)-3,7,12,16-tetramethyloctadeca-1,3,5,7,9,11,13,15,17-nonaen-1-yl]-3,5,5-trimethylcyclohex-3-en-1-ol', 'contains_ring_sugars': False, 'contains_linear_sugars': False, 'collection': [], 'molecular_formula': 'C40H56O2', 'molecular_weight': 568.8729279409029, 'geoLocation': ['asia'], 'npl_noh_score': 1.2641321271999277, 'npl_score': 0.9987013606321709, 'npl_sugar_score': 1.0536591878219577, 'number_of_carbons': 40, 'number_of_nitrogens': 0, 'number_of_oxygens': 2, 'max_number_of_rings': 2, 'min_number_of_rings': 2, 'sugar_free_heavy_atom_number': 42, 'sugar_free_total_atom_number': 98, 'total_atom_number': 98, 'bond_count': 43, 'found_in_databases': ['fooddb', 'chemspidernp', 'carotenoids', 'tcmdb_taiwan', 'supernatural2', 'tcmid', 'vietherb', 'zincnp', 'tipdb', 'respect', 'mnp', 'npact', 'cmaup', 'watermelondb', 'chebi_np', 'etmdb', 'knapsack', 'gnps', 'unpd', 'npass', 'exposome-explorer', 'pubchem'], 'xrefs': [['cmaup', 'NPC136514', 'http://bidd2.nus.edu.sg/CMAUP/searchresults.php?keyword_search='], ['chebi_np', '27547', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['knapsack', 'C00023218', 'http://www.knapsackfamily.com/knapsack_core/information.php?sname=C_ID&word='], ['chemspidernp', '4444421', 'http://www.chemspider.com/Chemical-Structure.'], ['cmaup', 'NPC45782', 'http://bidd2.nus.edu.sg/CMAUP/searchresults.php?keyword_search='], ['pubchem_tested_np', '534748', 'https://pubchem.ncbi.nlm.nih.gov/compound/'], ['carotenoids', 'CA00329', 'http://carotenoiddb.jp/Entries/'], ['supernatural2', 'SN00249216', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['chebi_np', '138919', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['supernatural2', 'SN00314336', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['fooddb', "(3R,3'R,9-cis)-beta,beta-Carotene-3,3'-diol", 'https://foodb.ca/compounds/'], ['supernatural2', 'SN00169291', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['knapsack', 'C00023219', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='],  ...
# {'_id': ObjectId('61a632d0c52bda1e67b9ac74'), 'coconut_id': 'CNP0216202', 'contains_sugar': 0, 'heavy_atom_number': 42, 'inchi': 'InChI=1S/C40H56O2/c1-29(17-13-19-31(3)21-23-37-33(5)25-35(41)27-39(37,7)8)15-11-12-16-30(2)18-14-20-32(4)22-24-38-34(6)26-36(42)28-40(38,9)10/h11-25,35-37,41-42H,26-28H2,1-10H3', 'inchikey': 'KBPHJBAIARWVSC-UHFFFAOYSA-N', 'smiles': '[H]OC1([H])C([H])=C(C([H])(C([H])=C([H])C(=C([H])C([H])=C([H])C(=C([H])C([H])=C([H])C([H])=C(C([H])=C([H])C([H])=C(C([H])=C([H])C2=C(C([H])([H])C([H])(O[H])C([H])([H])C2(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C(C1([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]', 'unique_smiles': 'OC1C=C(C)C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1', 'clean_smiles': 'OC1C=C(C)C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1', 'sugar_free_smiles': 'OC1C=C(C)C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1', 'deep_smiles': '', 'name': 'Bo-Xan', 'nameTrustLevel': 1, 'annotationLevel': 5, 'synonyms': ['(All-E)-Lutein', 'Lutein B', 'Xanthophyll', 'Lutein D', "(3R,3'R,6'R)-Beta,Epsilon-Carotene-3,3'-Diol", "(3R,3'R,6'S)-Beta,Epsilon-Carotene-3,3'-Diol", '4-[18-(4-Hydroxy-2,6,6-Trimethylcyclohex-1-En-1-Yl)-3,7,12,16-Tetramethyloctadeca-1,3,5,7,9,11,13,15,17-Nonaen-1-Yl]-3,5,5-Trimethylcyclohex-2-En-1-Ol', 'All-Trans-(+)-Xanthophyll', 'Lutein', 'E 161B', '(9Z)-Lutein', "(9'Z)-Lutein", 'Calthaxanthin', "(3R,3'S,6'R)-Beta,Epsilon-Carotene-3,3'-Diol", 'Bo-Xan', "(3R,3'S,6'S)-Beta,Epsilon-Carotene-3,3'-Diol", "(3R,3'R,6S)-4,5-Didehydro-5,6-Dihydro-Beta,Beta-Carotene-3,3'-Diol", "3'-Epilutein"], 'cas': '52842-48-5', 'iupac_name': '4-[18-(4-hydroxy-2,6,6-trimethylcyclohex-1-en-1-yl)-3,7,12,16-tetramethyloctadeca-1,3,5,7,9,11,13,15,17-nonaen-1-yl]-3,5,5-trimethylcyclohex-2-en-1-ol', 'contains_ring_sugars': False, 'contains_linear_sugars': False, 'collection': [], 'molecular_formula': 'C40H56O2', 'molecular_weight': 568.8729279409029, 'geoLocation': ['asia'], 'npl_noh_score': 1.5844982203519618, 'npl_score': 1.1193280087347734, 'npl_sugar_score': 1.1727861405701785, 'number_of_carbons': 40, 'number_of_nitrogens': 0, 'number_of_oxygens': 2, 'max_number_of_rings': 2, 'min_number_of_rings': 2, 'sugar_free_heavy_atom_number': 42, 'sugar_free_total_atom_number': 98, 'total_atom_number': 98, 'bond_count': 43, 'found_in_databases': ['fooddb', 'chemspidernp', 'carotenoids', 'tcmdb_taiwan', 'supernatural2', 'tcmid', 'vietherb', 'zincnp', 'phytolab', 'tipdb', 'mnp', 'npact', 'cmaup', 'watermelondb', 'chebi_np', 'etmdb', 'knapsack', 'hitdb', 'gnps', 'unpd', 'npass', 'exposome-explorer', 'pubchem'], 'xrefs': [['knapsack', 'C00003776', 'http://www.knapsackfamily.com/knapsack_core/information.php?sname=C_ID&word='], ['carotenoids', 'CA00597', 'http://carotenoiddb.jp/Entries/'], ['fooddb', 'Lutein_ester', 'https://foodb.ca/compounds/'], ['supernatural2', 'SN00364715', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['supernatural2', 'SN00431503', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['cmaup', 'NPC169786', 'http://bidd2.nus.edu.sg/CMAUP/searchresults.php?keyword_search='], ['supernatural2', 'SN00241180', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['chemspidernp', '17220874', 'http://www.chemspider.com/Chemical-Structure.'], ['knapsack', 'C00022873', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['chebi_np', 'CHEBI:28838', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['supernatural2', 'SN00366327', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['knapsack', 'C00035777', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['chemspidernp', '17220882', 'http://www.chemspider.com/Chemical-Structure.'], ['carotenoids', 'CA00615', 'http:/ ...
# {'_id': ObjectId('61a6998dc52bda1e67ba561d'), 'coconut_id': 'CNP0190579', 'contains_sugar': 0, 'heavy_atom_number': 44, 'inchi': 'InChI=1S/C40H52O4/c1-27(17-13-19-29(3)21-23-33-31(5)37(43)35(41)25-39(33,7)8)15-11-12-16-28(2)18-14-20-30(4)22-24-34-32(6)38(44)36(42)26-40(34,9)10/h11-24,35-36,41-42H,25-26H2,1-10H3', 'inchikey': 'MQZIGYBFDRPAKN-UHFFFAOYSA-N', 'smiles': '[H]OC1([H])C(=O)C(=C(C([H])=C([H])C(=C([H])C([H])=C([H])C(=C([H])C([H])=C([H])C([H])=C(C([H])=C([H])C([H])=C(C([H])=C([H])C2=C(C(=O)C([H])(O[H])C([H])([H])C2(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C(C1([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]', 'unique_smiles': 'O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C(=O)C(O)CC2(C)C)C)C)C)C)C)C(C)(C)CC1O)C', 'clean_smiles': 'O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C(=O)C(O)CC2(C)C)C)C)C)C)C)C(C)(C)CC1O)C', 'sugar_free_smiles': 'O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C(=O)C(O)CC2(C)C)C)C)C)C)C)C(C)(C)CC1O)C', 'deep_smiles': '', 'name': 'Ovoester', 'nameTrustLevel': 2, 'annotationLevel': 5, 'synonyms': ['Ovoester', 'E 161J', "All-Trans-(3S,3'S)-Astaxanthin", 'Astaxanthin', "(3S,3'S)-3,3'-Dihydroxy-Beta,Beta-Carotene-4,4'-Dione", "3,3'-Dihydroxy-Beta,Beta-Carotene-4,4'-Dione", "(3S,3'S)-Astaxanthin", "(3R,3'S)-3,3'-Dihydroxy-Beta,Beta-Carotene-4,4'-Dione", 'Meso-Astaxanthin', 'Astaxanthine', "(3R,3'R)-Astaxanthin", "(3R,3'S)-Astaxanthin", "3,3'-Dihydroxy-Beta-Carotene-4,4'-Dione", "(3R,3'R)-3,3'-Dihydroxy-Beta,Beta-Carotene-4,4'-Dione"], 'cas': '472-61-7', 'iupac_name': '6-hydroxy-3-[18-(4-hydroxy-2,6,6-trimethyl-3-oxocyclohex-1-en-1-yl)-3,7,12,16-tetramethyloctadeca-1,3,5,7,9,11,13,15,17-nonaen-1-yl]-2,4,4-trimethylcyclohex-2-en-1-one', 'contains_ring_sugars': False, 'contains_linear_sugars': False, 'collection': [], 'molecular_formula': 'C40H52O4', 'molecular_weight': 596.8399747807384, 'geoLocation': ['', 'asia'], 'npl_noh_score': 1.2453385964752604, 'npl_score': 0.9572613956298109, 'npl_sugar_score': 1.010327368572552, 'number_of_carbons': 40, 'number_of_nitrogens': 0, 'number_of_oxygens': 4, 'max_number_of_rings': 2, 'min_number_of_rings': 2, 'sugar_free_heavy_atom_number': 44, 'sugar_free_total_atom_number': 96, 'total_atom_number': 96, 'bond_count': 45, 'found_in_databases': ['fooddb', 'chemspidernp', 'carotenoids', 'tcmdb_taiwan', 'supernatural2', 'tcmid', 'zincnp', 'mnp', 'npatlas', 'chebi_np', 'npedia', 'knapsack', 'gnps', 'chembiosys_np', 'unpd', 'npass', 'pubchem'], 'xrefs': [['chemspidernp', '21188102', 'http://www.chemspider.com/Chemical-Structure.'], ['knapsack', 'C00023058', 'http://www.knapsackfamily.com/knapsack_core/information.php?sname=C_ID&word='], ['carotenoids', 'CA00551', 'http://carotenoiddb.jp/Entries/'], ['chebi_np', 'CHEBI:40968', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['supernatural2', 'SN00428258', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['knapsack', '4978', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['chemspidernp', '59700141', 'http://www.chemspider.com/Chemical-Structure.'], ['knapsack', 'C00000918', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['npass', '28901', 'http://bidd2.nus.edu.sg/NPASS/browse_np.php?compound='], ['carotenoids', 'CA00553', 'http://carotenoiddb.jp/Entries/'], ['carotenoids', 'CA00501', 'http://carotenoiddb.jp/Entries/'], ['supernatural2', 'SN00392566', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['supernatural2', 'SN00348161', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['supernatural2', 'SN00327894', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['chemspidernp', '25056557', 'http://www.chemspider.com/Chemical-Structure.'], ['knapsack', '656', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], [ ...
# {'_id': ObjectId('61a6d091c52bda1e67bab92b'), 'coconut_id': 'CNP0233748', 'contains_sugar': 0, 'heavy_atom_number': 40, 'inchi': 'InChI=1S/C40H56/c1-31(19-13-21-33(3)25-27-37-35(5)23-15-29-39(37,7)8)17-11-12-18-32(2)20-14-22-34(4)26-28-38-36(6)24-16-30-40(38,9)10/h11-14,17-22,25-28H,15-16,23-24,29-30H2,1-10H3', 'inchikey': 'OENHQHLEOONYIE-UHFFFAOYSA-N', 'smiles': '[H]C(C1=C(C([H])([H])C([H])([H])C([H])([H])C1(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])=C([H])C(=C([H])C([H])=C([H])C(=C([H])C([H])=C([H])C([H])=C(C([H])=C([H])C([H])=C(C([H])=C([H])C2=C(C([H])([H])C([H])([H])C([H])([H])C2(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]', 'unique_smiles': 'C(=CC=C(C=CC=C(C=CC1=C(C)CCCC1(C)C)C)C)C=C(C=CC=C(C=CC2=C(C)CCCC2(C)C)C)C', 'clean_smiles': 'C(=CC=C(C=CC=C(C=CC1=C(C)CCCC1(C)C)C)C)C=C(C=CC=C(C=CC2=C(C)CCCC2(C)C)C)C', 'sugar_free_smiles': 'C(=CC=C(C=CC=C(C=CC1=C(C)CCCC1(C)C)C)C)C=C(C=CC=C(C=CC2=C(C)CCCC2(C)C)C)C', 'deep_smiles': '', 'name': 'Beta', 'nameTrustLevel': 1, 'annotationLevel': 5, 'synonyms': ['Beta-Carotene', 'B-Carotene', '(9Z)-Beta,Beta-Carotene', 'all-trans-beta-carotene', "1,1'-[(1E,3E,5E,7E,9E,11E,13E,15E,17E)-3,7,12,16-Tetramethyloctadeca-1,3,5,7,9,11,13,15,17-Nonaene-1,18-Diyl]Bis(2,6,6-Trimethylcyclohexene)", '1,3,3-Trimethyl-2-[3,7,12,16-Tetramethyl-18-(2,6,6-Trimethylcyclohex-1-En-1-Yl)Octadeca-1,3,5,7,9,11,13,15,17-Nonaen-1-Yl]Cyclohex-1-Ene', '(13Z)-Beta,Beta-Carotene', '(15Z)-Beta,Beta-Carotene', 'Beta-Karotin', 'All-Trans-Beta-Carotene', '-Carotene', 'Beta'], 'cas': '7235-40-7', 'iupac_name': '1,3,3-trimethyl-2-[3,7,12,16-tetramethyl-18-(2,6,6-trimethylcyclohex-1-en-1-yl)octadeca-1,3,5,7,9,11,13,15,17-nonaen-1-yl]cyclohex-1-ene', 'contains_ring_sugars': False, 'contains_linear_sugars': False, 'collection': [], 'molecular_formula': 'C40H56', 'molecular_weight': 536.874118085764, 'geoLocation': ['asia'], 'npl_noh_score': 0.7650973891832474, 'npl_score': 0.7469746046385851, 'npl_sugar_score': 0.7728456096647012, 'number_of_carbons': 40, 'number_of_nitrogens': 0, 'number_of_oxygens': 0, 'max_number_of_rings': 2, 'min_number_of_rings': 2, 'sugar_free_heavy_atom_number': 40, 'sugar_free_total_atom_number': 96, 'total_atom_number': 96, 'bond_count': 41, 'found_in_databases': ['fooddb', 'chemspidernp', 'carotenoids', 'tcmdb_taiwan', 'supernatural2', 'zincnp', 'tipdb', 'chebi_np', 'etmdb', 'gnps', 'exposome-explorer', 'np-mrd', 'streptomedb', 'tcmid', 'vietherb', 'mnp', 'chembl_np', 'cmaup', 'streptomedb3', 'npedia', 'knapsack', 'unpd', 'pubchem_tested_np', 'npass', 'pubchem'], 'xrefs': [['supernatural2', 'SN00394684', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['knapsack', 'C00023248', 'http://www.knapsackfamily.com/knapsack_core/information.php?sname=C_ID&word='], ['pubchem_tested_np', '0', 'https://pubchem.ncbi.nlm.nih.gov/compound/'], ['chebi_np', 'CHEBI:17579', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['supernatural2', 'SN00339282', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['carotenoids', 'CA00311', 'http://carotenoiddb.jp/Entries/'], ['chemspidernp', '8432151', 'http://www.chemspider.com/Chemical-Structure.'], ['vietherb', '9768', 'https://vietherb.com.vn/metabolites/'], ['supernatural2', 'SN00161344', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['fooddb', '(9Z)-beta,beta-Carotene', 'https://foodb.ca/compounds/'], ['chebi_np', '17579', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['cmaup', 'NPC104168', 'http://bidd2.nus.edu.sg/CMAUP/searchresults.php?keyword_search='], ['fooddb', '(9Z)-beta-Carotene', 'https://foodb.ca/compounds/'], ['exposome-explorer', 'beta-Carotene_89', 'http://exposome-explorer.iarc.fr/compounds/'], ['knapsack', 'C00023249', 'http://www.knapsackfamily.com/knapsack_core/information.php?sname=C_ID&word='], ['supernatural2', 'SN00301745', 'http://bioinf-applied. ...
# {'_id': ObjectId('61a776a0c52bda1e67bbcd7f'), 'coconut_id': 'CNP0233524', 'contains_sugar': 0, 'heavy_atom_number': 48, 'inchi': 'InChI=1S/C42H58O6/c1-29(18-14-19-31(3)22-23-37-38(6,7)26-35(47-33(5)43)27-40(37,10)46)16-12-13-17-30(2)20-15-21-32(4)36(45)28-42-39(8,9)24-34(44)25-41(42,11)48-42/h12-22,34-35,44,46H,24-28H2,1-11H3', 'inchikey': 'SJWWTRQNNRNTPU-UHFFFAOYSA-N', 'smiles': '[H]OC1(C(=C=C([H])C(=C([H])C([H])=C([H])C(=C([H])C([H])=C([H])C([H])=C(C([H])=C([H])C([H])=C(C(=O)C([H])([H])C23OC2(C([H])([H])C([H])(O[H])C([H])([H])C3(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])C(C([H])([H])C([H])(OC(=O)C([H])([H])[H])C1([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]', 'unique_smiles': 'O=C(OC1CC(O)(C(=C=CC(=CC=CC(=CC=CC=C(C=CC=C(C(=O)CC23OC3(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1)C)C', 'clean_smiles': 'O=C(OC1CC(O)(C(=C=CC(=CC=CC(=CC=CC=C(C=CC=C(C(=O)CC23OC3(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1)C)C', 'sugar_free_smiles': 'O=C(OC1CC(O)(C(=C=CC(=CC=CC(=CC=CC=C(C=CC=C(C(=O)CC23OC3(C)CC(O)CC2(C)C)C)C)C)C)C(C)(C)C1)C)C', 'deep_smiles': '', 'name': 'Fucoxanthin', 'nameTrustLevel': 1, 'annotationLevel': 5, 'synonyms': ['3-Hydroxy-4-(18-{4-Hydroxy-2,2,6-Trimethyl-7-Oxabicyclo[4.1.0]Heptan-1-Yl}-3,7,12,16-Tetramethyl-17-Oxooctadeca-1,3,5,7,9,11,13,15-Octaen-1-Ylidene)-3,5,5-Trimethylcyclohexyl Acetate', "(3S,3'S,5R,5'R,6S,6'R)-3'-(Acetyloxy)-6',7'-Didehydro-5,6-Epoxy-5,5',6,6',7,8-Hexahydro-3,5'-Dihydroxy-8-Oxo-Beta,Beta-Carotene", "(3'S,5'R,6'R)-3'-Acetoxy-5,6-Epoxy-3,5'-Dihydroxy-6',7'-Didehydro-5,6,7,8,5',6'-Hexahydro-Beta,Beta-Caroten-8-One", 'Fucoxanthin'], 'cas': '3351-86-8', 'iupac_name': '3-hydroxy-4-(18-{4-hydroxy-2,2,6-trimethyl-7-oxabicyclo[4.1.0]heptan-1-yl}-3,7,12,16-tetramethyl-17-oxooctadeca-1,3,5,7,9,11,13,15-octaen-1-ylidene)-3,5,5-trimethylcyclohexyl acetate', 'contains_ring_sugars': False, 'contains_linear_sugars': False, 'collection': [], 'molecular_formula': 'C42H58O6', 'molecular_weight': 658.907900952408, 'geoLocation': ['africa', 'asia'], 'npl_noh_score': 1.764482092622666, 'npl_score': 1.2911606670917364, 'npl_sugar_score': 1.3417708860768696, 'number_of_carbons': 42, 'number_of_nitrogens': 0, 'number_of_oxygens': 6, 'max_number_of_rings': 4, 'min_number_of_rings': 3, 'sugar_free_heavy_atom_number': 48, 'sugar_free_total_atom_number': 106, 'total_atom_number': 106, 'bond_count': 50, 'found_in_databases': ['fooddb', 'chemspidernp', 'carotenoids', 'tcmdb_taiwan', 'sancdb', 'supernatural2', 'tcmid', 'inflamnat', 'nanpdb', 'zincnp', 'mnp', 'cmaup', 'chebi_np', 'npedia', 'knapsack', 'gnps', 'unpd', 'npass', 'npcare', 'cmnpd', 'pubchem'], 'xrefs': [['sancdb', 'SANC00246_minRM1.pdb', 'https://sancdb.rubi.ru.ac.za/compounds/'], ['chemspidernp', '4444651', 'http://www.chemspider.com/Chemical-Structure.'], ['knapsack', 'C00003773', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['supernatural2', 'SN00342417', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['cmaup', 'NPC268556', 'http://bidd2.nus.edu.sg/CMAUP/searchresults.php?keyword_search='], ['chebi_np', 'CHEBI:5186', 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:'], ['supernatural2', 'SN00390209', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['supernatural2', 'SN00171173', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['pubchem_tested_np', '541529', 'https://pubchem.ncbi.nlm.nih.gov/compound/'], ['supernatural2', 'SN00252623', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['knapsack', '4410', 'http://www.knapsackfamily.com/knapsack_core/information.php?mode=r&word='], ['tcmdb_taiwan', '8825', 'http://tcm.cmu.edu.tw/'], ['carotenoids', 'CA00519', 'http://carotenoiddb.jp/Entries/'], ['supernatural2', 'SN00341307', 'http://bioinf-applied.charite.de/supernatural_new/index.php?site=compound_search&id='], ['knap ...

# %%
bson_path = '/home/robaina/Databases/COCONUT_2021_11/uniqueNaturalProduct.bson'
compound_names = [
    "Beta-Carotene",
    "Astaxanthin",
    "Lutein",
    "Zeaxanthin",
    "Canthaxanthin",
    "Fucoxanthin",
]

found_compounds = find_compounds_by_name(bson_path, compound_names)

# %%
df_compounds = build_compound_dataframe(found_compounds)
df_compounds
# Out:
#    coconut_id         name                                           synonyms  \
# 0  CNP0355008    Orobronze  [Food Orange 8, 4,4'-Dioxo-Beta-Carotene, Caro...
# 1  CNP0283320   Zeaxanthin  [(3R,3'S)-Zeaxanthin, 4-[18-(4-Hydroxy-2,6,6-T...
# 2  CNP0216202       Bo-Xan  [(All-E)-Lutein, Lutein B, Xanthophyll, Lutein...
# 3  CNP0190579     Ovoester  [Ovoester, E 161J, All-Trans-(3S,3'S)-Astaxant...
# 4  CNP0233748         Beta  [Beta-Carotene, B-Carotene, (9Z)-Beta,Beta-Car...
# 5  CNP0233524  Fucoxanthin  [3-Hydroxy-4-(18-{4-Hydroxy-2,2,6-Trimethyl-7-...
#
#                                        unique_smiles  \
# 0  O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C...
# 1  OC1CC(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C...
# 2  OC1C=C(C)C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C...
# 3  O=C1C(=C(C=CC(=CC=CC(=CC=CC=C(C=CC=C(C=CC2=C(C...
# 4  C(=CC=C(C=CC=C(C=CC1=C(C)CCCC1(C)C)C)C)C=C(C=C...
# 5  O=C(OC1CC(O)(C(=C=CC(=CC=CC(=CC=CC=C(C=CC=C(C(...
#
#                                           iupac_name  molecular_weight  \
# 0  2,4,4-trimethyl-3-[3,7,12,16-tetramethyl-18-(2...        564.841165
# 1  4-[18-(4-hydroxy-2,6,6-trimethylcyclohex-1-en-...        568.872928
# 2  4-[18-(4-hydroxy-2,6,6-trimethylcyclohex-1-en-...        568.872928
# 3  6-hydroxy-3-[18-(4-hydroxy-2,6,6-trimethyl-3-o...        596.839975
# 4  1,3,3-trimethyl-2-[3,7,12,16-tetramethyl-18-(2...        536.874118
# 5  3-hydroxy-4-(18-{4-hydroxy-2,2,6-trimethyl-7-o...        658.907901
#
#    npl_score                                              taxid  \
# 0   0.714854                                                 []
# 1   0.998701  [48386, 502529, 36622, 4369, 134427, 4121, 183...
# 2   1.119328  [48386, 207754, 16719, 1672008, 29780, 340432,...
# 3   0.957261                                                 []
# 4   0.746975  [48386, 714511, 502529, 73737, 1209881, 49675,...
# 5   1.291161  [4081, 2850, 88149, 127572, 45367, 510735, 743...
#
#                                             textTaxa  \
# 0  [Cantharellus cinnabarinus, Anabaena flos-aqua...
# 1  [Prosopis glandulosa, Agnorhiza bolanderi, Tax...
# 2  [Begonia nantoensis, Citrus sinensis, Pelteoba...
# 3  [Pfaffia rhodozyma, Pelteobagrus nudiceps, Ado...
# 4  [Prosopis glandulosa, Agnorhiza bolanderi, Tax...
# 5  [Corbicula sandai, Sargassum fusiforme, Cratae...
#
#                 chemicalSuperClass  chemicalClass chemicalSubClass  \
# 0  Lipids and lipid-like molecules  Prenol lipids  Tetraterpenoids
# 1  Lipids and lipid-like molecules  Prenol lipids  Tetraterpenoids
# 2  Lipids and lipid-like molecules  Prenol lipids  Tetraterpenoids
# 3  Lipids and lipid-like molecules  Prenol lipids  Tetraterpenoids
# 4  Lipids and lipid-like molecules  Prenol lipids  Tetraterpenoids
# 5  Lipids and lipid-like molecules  Prenol lipids  Tetraterpenoids
#
#   directParentClassification
# 0               Xanthophylls
# 1               Xanthophylls
# 2               Xanthophylls
# 3               Xanthophylls
# 4                  Carotenes
# 5               Xanthophylls
